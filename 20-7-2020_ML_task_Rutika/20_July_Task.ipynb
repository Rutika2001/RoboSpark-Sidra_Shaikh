# %% [markdown]
# **Libraries used**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **reading csv file and loaded into df**

# %%
df=pd.read_csv('house_data.csv')

# %%
df
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000   221900.0         3       1.00         1180
# 1   6414100192  20141209T000000   538000.0         3       2.25         2570
# 2   5631500400  20150225T000000   180000.0         2       1.00          770
# 3   2487200875  20141209T000000   604000.0         4       3.00         1960
# 4   1954400510  20150218T000000   510000.0         3       2.00         1680
# 5   7237550310  20140512T000000  1230000.0         4       4.50         5420
# 6   1321400060  20140627T000000   257500.0         3       2.25         1715
# 7   2008000270  20150115T000000   291850.0         3       1.50         1060
# 8   2414600126  20150415T000000   229500.0         3       1.00         1780
# 9   3793500160  20150312T000000   323000.0         3       2.50         1890
# 10  1736800520  20150403T000000   662500.0         3       2.50         3560
# ...

# %%
data={'id':[0,1],'date':['20141023T000000','20140813T000000'],
       'price':['20000.0','23230.0'],'bedrooms':[4,3],'bathrooms':['2.25','3.00'],'sqrt_living':['2560','1112'],
         'sqrt_lot':['3422','5643'],'floors':['2.0','1.0']}
df=pd.DataFrame(data)

# %%
df
# Out:
#    id             date    price  bedrooms bathrooms sqrt_living sqrt_lot  \
# 0   0  20141023T000000  20000.0         4      2.25        2560     3422
# 1   1  20140813T000000  23230.0         3      3.00        1112     5643
#
#   floors
# 0    2.0
# 1    1.0

# %%
df.shape
# Out:
# (99, 8)

# %%
df.describe()
# Out:
#                  id         price   bedrooms  bathrooms  sqft_living  \
# count  9.900000e+01  9.900000e+01  99.000000  99.000000    99.000000
# mean   4.664620e+09  5.200763e+05   3.404040   1.989899  2086.383838
# std    2.935212e+09  3.061939e+05   0.794358   0.729236   864.592421
# min    1.600040e+07  1.530000e+05   2.000000   1.000000   770.000000
# 25%    1.914950e+09  3.070000e+05   3.000000   1.500000  1410.000000
# 50%    4.036801e+09  4.300000e+05   3.000000   2.000000  1900.000000
# 75%    7.337325e+09  6.562500e+05   4.000000   2.500000  2570.000000
# max    9.822700e+09  2.000000e+06   5.000000   4.500000  5420.000000
#
#             sqft_lot     floors
# count      99.000000  99.000000
# mean    11478.818182   1.464646
# std     14655.249813   0.511363
# min      1044.000000   1.000000
# 25%      5000.000000   1.000000
# 50%      6720.000000   1.500000
# 75%      9823.000000   2.000000
# max    101930.000000   3.000000

# %%
df.info()  #general info about data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           99 non-null     int64
#  1   date         99 non-null     object
#  2   price        99 non-null     float64
#  3   bedrooms     99 non-null     int64
#  4   bathrooms    99 non-null     float64
#  5   sqft_living  99 non-null     int64
#  6   sqft_lot     99 non-null     int64
#  7   floors       99 non-null     float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 6.3+ KB

# %%
df.head(5)  #top 5 elements
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors
# 0      5650     1.0
# 1      7242     2.0
# 2     10000     1.0
# 3      5000     1.0
# 4      8080     1.0

# %%
df.tail(5)   #last 5 elements
# Out:
#             id             date     price  bedrooms  bathrooms  sqft_living  \
# 94  6021501535  20141223T000000  700000.0         3       1.50         1580
# 95  1483300570  20140908T000000  905000.0         4       2.50         3300
# 96  3422049190  20150330T000000  247500.0         3       1.75         1960
# 97  1099611230  20140912T000000  199000.0         4       1.50         1160
# 98   722079104  20140711T000000  314000.0         3       1.75         1810
#
#     sqft_lot  floors
# 94      5000     1.0
# 95     10250     1.0
# 96     15681     1.0
# 97      6400     1.0
# 98     41800     1.0

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors'],
#       dtype='object')

# %%
df['date']
# Out:
# 0     20141013T000000
# 1     20141209T000000
# 2     20150225T000000
# 3     20141209T000000
# 4     20150218T000000
# 5     20140512T000000
# 6     20140627T000000
# 7     20150115T000000
# 8     20150415T000000
# 9     20150312T000000
# 10    20150403T000000
# 11    20140527T000000
# 12    20140528T000000
# 13    20141007T000000
# 14    20150312T000000
# 15    20150124T000000
# 16    20140731T000000
# 17    20140529T000000
# 18    20141205T000000
# 19    20150424T000000
# 20    20140514T000000
# 21    20140826T000000
# 22    20140703T000000
# 23    20140516T000000
# 24    20141120T000000
# 25    20141103T000000
# 26    20140626T000000
# 27    20141201T000000
# 28    20140624T000000
# 29    20150302T000000
# 30    20141110T000000
# 31    20141201T000000
# 32    20140624T000000
# 33    20141110T000000
# 34    20141203T000000
# 35    20140613T000000
# 36    20140528T000000
# 37    20141230T000000
# 38    20150213T000000
# 39    20140620T000000
# 40    20140715T000000
# ...

# %%
df[['date','price']]
# Out:
#                date      price
# 0   20141013T000000   221900.0
# 1   20141209T000000   538000.0
# 2   20150225T000000   180000.0
# 3   20141209T000000   604000.0
# 4   20150218T000000   510000.0
# 5   20140512T000000  1230000.0
# 6   20140627T000000   257500.0
# 7   20150115T000000   291850.0
# 8   20150415T000000   229500.0
# 9   20150312T000000   323000.0
# 10  20150403T000000   662500.0
# 11  20140527T000000   468000.0
# 12  20140528T000000   310000.0
# 13  20141007T000000   400000.0
# 14  20150312T000000   530000.0
# 15  20150124T000000   650000.0
# 16  20140731T000000   395000.0
# 17  20140529T000000   485000.0
# 18  20141205T000000   189000.0
# 19  20150424T000000   230000.0
# 20  20140514T000000   385000.0
# 21  20140826T000000  2000000.0
# 22  20140703T000000   285000.0
# 23  20140516T000000   252700.0
# 24  20141120T000000   329000.0
# 25  20141103T000000   233000.0
# 26  20140626T000000   937000.0
# 27  20141201T000000   667000.0
# 28  20140624T000000   438000.0
# ...

# %%
df.price.max()
# Out:
# 2000000.0

# %%
df.price.min()
# Out:
# 153000.0

# %%
df.price.mean()
# Out:
# 520076.31313131313

# %%
df.fillna(0,inplace=True)
df.price.mean()
# Out:
# 520076.31313131313

# %%
df['floors'].replace(to_replace = np.nan, value = 0, inplace = True)

# %%
df.floors.isnull().sum()
# Out:
# 0

# %%
df.floors.count()
# Out:
# 99

# %%
df.bedrooms.unique()
# Out:
# array([3, 2, 4, 5], dtype=int64)

# %%
df.loc[5]
# Out:
# id                  7237550310
# date           20140512T000000
# price                 1.23e+06
# bedrooms                     4
# bathrooms                  4.5
# sqft_living               5420
# sqft_lot                101930
# floors                       1
# Name: 5, dtype: object

# %%
df.set_index('id')
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000   221900.0         3       1.00         1180
# 6414100192  20141209T000000   538000.0         3       2.25         2570
# 5631500400  20150225T000000   180000.0         2       1.00          770
# 2487200875  20141209T000000   604000.0         4       3.00         1960
# 1954400510  20150218T000000   510000.0         3       2.00         1680
# 7237550310  20140512T000000  1230000.0         4       4.50         5420
# 1321400060  20140627T000000   257500.0         3       2.25         1715
# 2008000270  20150115T000000   291850.0         3       1.50         1060
# 2414600126  20150415T000000   229500.0         3       1.00         1780
# 3793500160  20150312T000000   323000.0         3       2.50         1890
# 1736800520  20150403T000000   662500.0         3       2.50         3560
# 9212900260  20140527T000000   468000.0         2       1.00         1160
# ...

# %%
df.reset_index()
# Out:
#     index          id             date      price  bedrooms  bathrooms  \
# 0       0  7129300520  20141013T000000   221900.0         3       1.00
# 1       1  6414100192  20141209T000000   538000.0         3       2.25
# 2       2  5631500400  20150225T000000   180000.0         2       1.00
# 3       3  2487200875  20141209T000000   604000.0         4       3.00
# 4       4  1954400510  20150218T000000   510000.0         3       2.00
# 5       5  7237550310  20140512T000000  1230000.0         4       4.50
# 6       6  1321400060  20140627T000000   257500.0         3       2.25
# 7       7  2008000270  20150115T000000   291850.0         3       1.50
# 8       8  2414600126  20150415T000000   229500.0         3       1.00
# 9       9  3793500160  20150312T000000   323000.0         3       2.50
# 10     10  1736800520  20150403T000000   662500.0         3       2.50
# 11     11  9212900260  20140527T000000   468000.0         2       1.00
# ...

# %%
df.rename(columns={'date':'Dates'},inplace=True)

# %%
df.head()
# Out:
#            id            Dates     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors
# 0      5650     1.0
# 1      7242     2.0
# 2     10000     1.0
# 3      5000     1.0
# 4      8080     1.0

# %% [markdown]
# **one hat Encoding**

# %%
dummies=pd.get_dummies(df.bedrooms)

# %%
df = pd.concat([df,dummies],axis='columns')

# %%
df.head()
# Out:
#            id            Dates     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  2  3  4  5
# 0      5650     1.0  0  1  0  0
# 1      7242     2.0  0  1  0  0
# 2     10000     1.0  1  0  0  0
# 3      5000     1.0  0  0  1  0
# 4      8080     1.0  0  1  0  0

# %%
df=df.drop(['bathrooms'],axis='columns')

# %% [markdown]
# **Spliting using pandas**

# %%
df1=df.copy()

# %%
House_data=df1.sample(frac=0.75,random_state=1)
test=df1.drop(House_data.index)

# %%
test.count()
# Out:
# id             25
# Dates          25
# price          25
# bedrooms       25
# sqft_living    25
# sqft_lot       25
# floors         25
# 2              25
# 3              25
# 4              25
# 5              25
# dtype: int64

# %%
House_data.count()
# Out:
# id             74
# Dates          74
# price          74
# bedrooms       74
# sqft_living    74
# sqft_lot       74
# floors         74
# 2              74
# 3              74
# 4              74
# 5              74
# dtype: int64

# %% [markdown]
# **Spliting using Scikit-Learn**

# %%
from sklearn.model_selection import train_test_split

# %%
x,y=np.arange(15).reshape((5,3)),range(5)

# %%
 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
x_train
# Out:
# array([[ 6,  7,  8],
#        [ 0,  1,  2],
#        [ 9, 10, 11]])

# %%
y_train
# Out:
# [2, 0, 3]

# %%
train_test_split(y, shuffle=False)
# Out:
# [[0, 1, 2], [3, 4]]
